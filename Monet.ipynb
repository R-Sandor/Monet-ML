# %% [markdown]
# # Project 2.
# # I'm Something Of a Painter Myself
# ### Raphael J. Sandor
# ### Old Dominion University
# #### 3/27/2022

# %% [markdown]
# # Imports
# Copied recommend imports for Monet project from https://www.kaggle.com/code/amyjang/monet-cyclegan-tutorial/notebook

# %%
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
import tensorflow_addons as tfa

import matplotlib.pyplot as plt
import numpy as np

try:
    tpu = tf.distribute.cluster_resolver.TPUClusterResolver()
    print('Device:', tpu.master())
    tf.config.experimental_connect_to_cluster(tpu)
    tf.tpu.experimental.initialize_tpu_system(tpu)
    strategy = tf.distribute.experimental.TPUStrategy(tpu)
except:
    strategy = tf.distribute.get_strategy()
print('Number of replicas:', strategy.num_replicas_in_sync)

AUTOTUNE = tf.data.experimental.AUTOTUNE
    
print(tf.__version__)
# Out:
# Number of replicas: 1
# 2.8.0

# %% [markdown]
# # Global Data

# %%
TFRECORD_DIR = 'tfrecords'

# Model Parameters
HEIGHT = 256
WIDTH = 256
HEIGHT_RESIZE = 128
WIDTH_RESIZE = 128
CHANNELS = 3
BATCH_SIZE = 16
EPOCHS = 120
TRANSFORMER_BLOCKS = 6
GENERATOR_LR = 2e-4
DISCRIMINATOR_LR = 2e-4



MONET_FILENAMES = tf.io.gfile.glob(str(TFRECORD_DIR + '/monet_tfrec/*.tfrec'))
print('Monet TFRecord Files:', len(MONET_FILENAMES))

PHOTO_FILENAMES = tf.io.gfile.glob(str(TFRECORD_DIR + '/photo_tfrec/*.tfrec'))
print('Photo TFRecord Files:', len(PHOTO_FILENAMES))
# Out:
# Monet TFRecord Files: 5
# Photo TFRecord Files: 20

# %% [markdown]
# # TFRecords

# %%
IMAGE_SIZE = [256, 256]

def decode_image(image):
    image = tf.image.decode_jpeg(image, channels=CHANNELS)
    image = (tf.cast(image, tf.float32) / 127.5) - 1
    image = tf.reshape(image, [*IMAGE_SIZE, 3])
    return image

def read_tfrecord(example):
    tfrecord_format = {
        "image_name": tf.io.FixedLenFeature([], tf.string),
        "image": tf.io.FixedLenFeature([], tf.string),
        "target": tf.io.FixedLenFeature([], tf.string)
    }
    example = tf.io.parse_single_example(example, tfrecord_format)
    image = decode_image(example['image'])
    return image

# %%
def load_dataset(filenames, labeled=True, ordered=False):
    dataset = tf.data.TFRecordDataset(filenames)
    dataset = dataset.map(read_tfrecord, num_parallel_calls=AUTOTUNE)
    return dataset

# %%
monet_ds = load_dataset(MONET_FILENAMES, labeled=True).batch(1)
photo_ds = load_dataset(PHOTO_FILENAMES, labeled=True).batch(1)
# Out:
# 2022-04-11 06:38:31.633959: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:936] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-04-11 06:38:31.730408: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:936] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-04-11 06:38:31.730558: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:936] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-04-11 06:38:31.732150: I tensorflow/core/platform/cpu_feature_guard.cc:151] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2022-04-11 06:38:31.732411: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:936] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-04-11 06:38:31.732541: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:936] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-04-11 06:38:31.732651: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:936] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-04-11 06:38:32.856190: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:936] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-04-11 06:38:32.856354: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:936] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-04-11 06:38:32.856470: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:936] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-04-11 06:38:32.857236: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1525] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 4017 MB memory:  -> device: 0, name: NVIDIA GeForce GTX 1660 SUPER, pci bus id: 0000:01:00.0, compute capability: 7.5

# %%
example_monet = next(iter(monet_ds))
example_photo = next(iter(photo_ds))

# %%
plt.subplot(121)
plt.title('Photo')
plt.imshow(example_photo[0] * 0.5 + 0.5)

plt.subplot(122)
plt.title('Monet')
plt.imshow(example_monet[0] * 0.5 + 0.5)

# %% [markdown]
# ## Downsampling and Upsampling

# %%
OUTPUT_CHANNELS = 3

def downsample(filters, size, apply_instancenorm=True):
    initializer = tf.random_normal_initializer(0., 0.02)
    gamma_init = keras.initializers.RandomNormal(mean=0.0, stddev=0.02)

    result = keras.Sequential()
    result.add(layers.Conv2D(filters, size, strides=2, padding='same',
                             kernel_initializer=initializer, use_bias=False))

    if apply_instancenorm:
        result.add(tfa.layers.InstanceNormalization(gamma_initializer=gamma_init))

    result.add(layers.LeakyReLU())

    return result

# %%
def upsample(filters, size, apply_dropout=False):
    initializer = tf.random_normal_initializer(0., 0.02)
    gamma_init = keras.initializers.RandomNormal(mean=0.0, stddev=0.02)

    result = keras.Sequential()
    result.add(layers.Conv2DTranspose(filters, size, strides=2,
                                      padding='same',
                                      kernel_initializer=initializer,
                                      use_bias=False))

    result.add(tfa.layers.InstanceNormalization(gamma_initializer=gamma_init))

    if apply_dropout:
        result.add(layers.Dropout(0.5))

    result.add(layers.ReLU())

    return result

# %%
# Borrowed from: https://www.kaggle.com/code/dimitreoliveira/improving-cyclegan-monet-paintings/notebook
def transformer_block(input_layer, size=3, strides=1, name='block_x'):
    filters = input_layer.shape[-1]
    initializer = tf.random_normal_initializer(0., 0.02)

    block = layers.Conv2D(filters, size, strides=strides, padding='same', use_bias=False, 
                     kernel_initializer=initializer, name=f'transformer_{name}_1')(input_layer)
#     block = tfa.layers.InstanceNormalization(gamma_initializer=gamma_initializer)(block)
    block = layers.ReLU()(block)
    
    block = layers.Conv2D(filters, size, strides=strides, padding='same', use_bias=False, 
                     kernel_initializer=initializer, name=f'transformer_{name}_2')(block)
#     block = tfa.layers.InstanceNormalization(gamma_initializer=gamma_initializer)(block)
    
    block = layers.Add()([block, input_layer])

    return block

# %% [markdown]
# # Build the Generator

# %%
def Generator(height=HEIGHT, width=WIDTH, channels=CHANNELS, transformer_blocks=TRANSFORMER_BLOCKS):
    inputs = layers.Input(shape=[height,width, channels], name='input_image')

    # bs = batch size
    down_stack = [
        downsample(64, 4, apply_instancenorm=False), # (bs, 128, 128, 64)
        downsample(128, 4), # (bs, 64, 64, 128)
        downsample(256, 4), # (bs, 32, 32, 256)
        downsample(512, 4), # (bs, 16, 16, 512)
        downsample(512, 4), # (bs, 8, 8, 512)
        downsample(512, 4), # (bs, 4, 4, 512)
        downsample(512, 4), # (bs, 2, 2, 512)
        downsample(512, 4), # (bs, 1, 1, 512)
    ]

    up_stack = [
        upsample(512, 4, apply_dropout=True), # (bs, 2, 2, 1024)
        upsample(512, 4, apply_dropout=True), # (bs, 4, 4, 1024)
        upsample(512, 4, apply_dropout=True), # (bs, 8, 8, 1024)
        upsample(512, 4), # (bs, 16, 16, 1024)
        upsample(256, 4), # (bs, 32, 32, 512)
        upsample(128, 4), # (bs, 64, 64, 256)
        upsample(64, 4), # (bs, 128, 128, 128)
    ]

    initializer = tf.random_normal_initializer(0., 0.02)
    last = layers.Conv2DTranspose(OUTPUT_CHANNELS, 4,
                                  strides=2,
                                  padding='same',
                                  kernel_initializer=initializer,
                                  activation='tanh') # (bs, 256, 256, 3)

    x = inputs

    # Downsampling through the model
    skips = []
    for down in down_stack:
        x = down(x)
        skips.append(x)

    skips = reversed(skips[:-1])
    
    # Transformer    
    ## Added Transformer example from: https://www.kaggle.com/code/dimitreoliveira/improving-cyclegan-monet-paintings/notebook
    for n in range(transformer_blocks):
        x = transformer_block(x, 3, 1, name=f'block_{n+1}') # (bs, 64, 64, 256)


    # Upsampling and establishing the skip connections
    for up, skip in zip(up_stack, skips):
        x = up(x)
        x = layers.Concatenate()([x, skip])

    x = last(x)

    return keras.Model(inputs=inputs, outputs=x)

sample_generator = Generator()
sample_generator.summary()
# Out:
# Model: "model_5"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_image (InputLayer)       [(None, 256, 256, 3  0           []
#                                 )]
#
#  sequential_39 (Sequential)     (None, 128, 128, 64  3072        ['input_image[0][0]']
#                                 )
#
#  sequential_40 (Sequential)     (None, 64, 64, 128)  131328      ['sequential_39[0][0]']
#
#  sequential_41 (Sequential)     (None, 32, 32, 256)  524800      ['sequential_40[0][0]']
#
#  sequential_42 (Sequential)     (None, 16, 16, 512)  2098176     ['sequential_41[0][0]']
#
#  sequential_43 (Sequential)     (None, 8, 8, 512)    4195328     ['sequential_42[0][0]']
#
#  sequential_44 (Sequential)     (None, 4, 4, 512)    4195328     ['sequential_43[0][0]']
#
#  sequential_45 (Sequential)     (None, 2, 2, 512)    4195328     ['sequential_44[0][0]']
#
#  sequential_46 (Sequential)     (None, 1, 1, 512)    4195328     ['sequential_45[0][0]']
#
#  transformer_block_1_1 (Conv2D)  (None, 1, 1, 512)   2359296     ['sequential_46[0][0]']
#
#  re_lu_33 (ReLU)                (None, 1, 1, 512)    0           ['transformer_block_1_1[0][0]']
#
#  transformer_block_1_2 (Conv2D)  (None, 1, 1, 512)   2359296     ['re_lu_33[0][0]']
#
#  add_12 (Add)                   (None, 1, 1, 512)    0           ['transformer_block_1_2[0][0]',
#                                                                   'sequential_46[0][0]']
#
#  transformer_block_2_1 (Conv2D)  (None, 1, 1, 512)   2359296     ['add_12[0][0]']
#
#  re_lu_34 (ReLU)                (None, 1, 1, 512)    0           ['transformer_block_2_1[0][0]']
#
#  transformer_block_2_2 (Conv2D)  (None, 1, 1, 512)   2359296     ['re_lu_34[0][0]']
#
#  add_13 (Add)                   (None, 1, 1, 512)    0           ['transformer_block_2_2[0][0]',
#                                                                   'add_12[0][0]']
#
#  transformer_block_3_1 (Conv2D)  (None, 1, 1, 512)   2359296     ['add_13[0][0]']
#
#  re_lu_35 (ReLU)                (None, 1, 1, 512)    0           ['transformer_block_3_1[0][0]']
#
#  transformer_block_3_2 (Conv2D)  (None, 1, 1, 512)   2359296     ['re_lu_35[0][0]']
#
#  add_14 (Add)                   (None, 1, 1, 512)    0           ['transformer_block_3_2[0][0]',
#                                                                   'add_13[0][0]']
#
#  transformer_block_4_1 (Conv2D)  (None, 1, 1, 512)   2359296     ['add_14[0][0]']
#
#  re_lu_36 (ReLU)                (None, 1, 1, 512)    0           ['transformer_block_4_1[0][0]']
#
#  transformer_block_4_2 (Conv2D)  (None, 1, 1, 512)   2359296     ['re_lu_36[0][0]']
#
#  add_15 (Add)                   (None, 1, 1, 512)    0           ['transformer_block_4_2[0][0]',
#                                                                   'add_14[0][0]']
#
#  transformer_block_5_1 (Conv2D)  (None, 1, 1, 512)   2359296     ['add_15[0][0]']
#
#  re_lu_37 (ReLU)                (None, 1, 1, 512)    0           ['transformer_block_5_1[0][0]']
#
#  transformer_block_5_2 (Conv2D)  (None, 1, 1, 512)   2359296     ['re_lu_37[0][0]']
#
#  add_16 (Add)                   (None, 1, 1, 512)    0           ['transformer_block_5_2[0][0]',
#                                                                   'add_15[0][0]']
#
#  transformer_block_6_1 (Conv2D)  (None, 1, 1, 512)   2359296     ['add_16[0][0]']
#
#  re_lu_38 (ReLU)                (None, 1, 1, 512)    0           ['transformer_block_6_1[0][0]']
#
#  transformer_block_6_2 (Conv2D)  (None, 1, 1, 512)   2359296     ['re_lu_38[0][0]']
#
#  add_17 (Add)                   (None, 1, 1, 512)    0           ['transformer_block_6_2[0][0]',
#                                                                   'add_16[0][0]']
#
#  sequential_47 (Sequential)     (None, 2, 2, 512)    4195328     ['add_17[0][0]']
#
#  concatenate_14 (Concatenate)   (None, 2, 2, 1024)   0           ['sequential_47[0][0]',
#                                                                   'sequential_45[0][0]']
#
#  sequential_48 (Sequential)     (None, 4, 4, 512)    8389632     ['concatenate_14[0][0]']
#
#  concatenate_15 (Concatenate)   (None, 4, 4, 1024)   0           ['sequential_48[0][0]',
#                                                                   'sequential_44[0][0]']
#
#  sequential_49 (Sequential)     (None, 8, 8, 512)    8389632     ['concatenate_15[0][0]']
#
#  concatenate_16 (Concatenate)   (None, 8, 8, 1024)   0           ['sequential_49[0][0]',
#                                                                   'sequential_43[0][0]']
#
#  sequential_50 (Sequential)     (None, 16, 16, 512)  8389632     ['concatenate_16[0][0]']
#
#  concatenate_17 (Concatenate)   (None, 16, 16, 1024  0           ['sequential_50[0][0]',
#                                 )                                 'sequential_42[0][0]']
#
#  sequential_51 (Sequential)     (None, 32, 32, 256)  4194816     ['concatenate_17[0][0]']
#
#  concatenate_18 (Concatenate)   (None, 32, 32, 512)  0           ['sequential_51[0][0]',
#                                                                   'sequential_41[0][0]']
#
#  sequential_52 (Sequential)     (None, 64, 64, 128)  1048832     ['concatenate_18[0][0]']
#
#  concatenate_19 (Concatenate)   (None, 64, 64, 256)  0           ['sequential_52[0][0]',
#                                                                   'sequential_40[0][0]']
#
#  sequential_53 (Sequential)     (None, 128, 128, 64  262272      ['concatenate_19[0][0]']
#                                 )
#
#  concatenate_20 (Concatenate)   (None, 128, 128, 12  0           ['sequential_53[0][0]',
#                                 8)                                'sequential_39[0][0]']
#
#  conv2d_transpose_23 (Conv2DTra  (None, 256, 256, 3)  6147       ['concatenate_20[0][0]']
#  nspose)
#
# ==================================================================================================
# Total params: 82,726,531
# Trainable params: 82,726,531
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %% [markdown]
# ## Building the Discriminator

# %%
def Discriminator():
    initializer = tf.random_normal_initializer(0., 0.02)
    gamma_init = keras.initializers.RandomNormal(mean=0.0, stddev=0.02)

    inp = layers.Input(shape=[256, 256, 3], name='input_image')

    x = inp

    down1 = downsample(64, 4, False)(x) # (bs, 128, 128, 64)
    down2 = downsample(128, 4)(down1) # (bs, 64, 64, 128)
    down3 = downsample(256, 4)(down2) # (bs, 32, 32, 256)

    zero_pad1 = layers.ZeroPadding2D()(down3) # (bs, 34, 34, 256)
    conv = layers.Conv2D(512, 4, strides=1,
                         kernel_initializer=initializer,
                         use_bias=False)(zero_pad1) # (bs, 31, 31, 512)

    norm1 = tfa.layers.InstanceNormalization(gamma_initializer=gamma_init)(conv)

    leaky_relu = layers.LeakyReLU()(norm1)

    zero_pad2 = layers.ZeroPadding2D()(leaky_relu) # (bs, 33, 33, 512)

    last = layers.Conv2D(1, 4, strides=1,
                         kernel_initializer=initializer)(zero_pad2) # (bs, 30, 30, 1)

    return tf.keras.Model(inputs=inp, outputs=last)

sample_discriminator = Discriminator()
sample_discriminator.summary()
# Out:
# Model: "model_4"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_image (InputLayer)    [(None, 256, 256, 3)]     0
#
#  sequential_36 (Sequential)  (None, 128, 128, 64)      3072
#
#  sequential_37 (Sequential)  (None, 64, 64, 128)       131328
#
#  sequential_38 (Sequential)  (None, 32, 32, 256)       524800
#
#  zero_padding2d_4 (ZeroPaddi  (None, 34, 34, 256)      0
#  ng2D)
#
#  conv2d_29 (Conv2D)          (None, 31, 31, 512)       2097152
#
#  instance_normalization_36 (  (None, 31, 31, 512)      1024
#  InstanceNormalization)
#
#  leaky_re_lu_27 (LeakyReLU)  (None, 31, 31, 512)       0
#
#  zero_padding2d_5 (ZeroPaddi  (None, 33, 33, 512)      0
#  ng2D)
#
#  conv2d_30 (Conv2D)          (None, 30, 30, 1)         8193
#
# =================================================================
# Total params: 2,765,569
# Trainable params: 2,765,569
# Non-trainable params: 0
# _________________________________________________________________

# %%
with strategy.scope():
    monet_generator = Generator() # transforms photos to Monet-esque paintings
    photo_generator = Generator() # transforms Monet paintings to be more like photos

    monet_discriminator = Discriminator() # differentiates real Monet paintings and generated Monet paintings
    photo_discriminator = Discriminator() # differentiates real photos and generated photos

# %%
to_monet = monet_generator(example_photo)

plt.subplot(1, 2, 1)
plt.title("Original Photo")
plt.imshow(example_photo[0] * 0.5 + 0.5)

plt.subplot(1, 2, 2)
plt.title("Monet-esque Photo")
plt.imshow(to_monet[0] * 0.5 + 0.5)
plt.show()
# Out:
# 2022-04-11 06:38:36.751188: I tensorflow/stream_executor/cuda/cuda_dnn.cc:368] Loaded cuDNN version 8400

# %% [markdown]
# # Build the CycleGAN Model

# %%
class CycleGan(keras.Model):
    def __init__(
        self,
        monet_generator,
        photo_generator,
        monet_discriminator,
        photo_discriminator,
        lambda_cycle=10,
    ):
        super(CycleGan, self).__init__()
        self.m_gen = monet_generator
        self.p_gen = photo_generator
        self.m_disc = monet_discriminator
        self.p_disc = photo_discriminator
        self.lambda_cycle = lambda_cycle
        
    def compile(
        self,
        m_gen_optimizer,
        p_gen_optimizer,
        m_disc_optimizer,
        p_disc_optimizer,
        gen_loss_fn,
        disc_loss_fn,
        cycle_loss_fn,
        identity_loss_fn
    ):
        super(CycleGan, self).compile()
        self.m_gen_optimizer = m_gen_optimizer
        self.p_gen_optimizer = p_gen_optimizer
        self.m_disc_optimizer = m_disc_optimizer
        self.p_disc_optimizer = p_disc_optimizer
        self.gen_loss_fn = gen_loss_fn
        self.disc_loss_fn = disc_loss_fn
        self.cycle_loss_fn = cycle_loss_fn
        self.identity_loss_fn = identity_loss_fn
        
    def train_step(self, batch_data):
        real_monet, real_photo = batch_data
        
        with tf.GradientTape(persistent=True) as tape:
            # photo to monet back to photo
            fake_monet = self.m_gen(real_photo, training=True)
            cycled_photo = self.p_gen(fake_monet, training=True)

            # monet to photo back to monet
            fake_photo = self.p_gen(real_monet, training=True)
            cycled_monet = self.m_gen(fake_photo, training=True)

            # generating itself
            same_monet = self.m_gen(real_monet, training=True)
            same_photo = self.p_gen(real_photo, training=True)

            # discriminator used to check, inputing real images
            disc_real_monet = self.m_disc(real_monet, training=True)
            disc_real_photo = self.p_disc(real_photo, training=True)

            # discriminator used to check, inputing fake images
            disc_fake_monet = self.m_disc(fake_monet, training=True)
            disc_fake_photo = self.p_disc(fake_photo, training=True)

            # evaluates generator loss
            monet_gen_loss = self.gen_loss_fn(disc_fake_monet)
            photo_gen_loss = self.gen_loss_fn(disc_fake_photo)

            # evaluates total cycle consistency loss
            total_cycle_loss = self.cycle_loss_fn(real_monet, cycled_monet, self.lambda_cycle) + self.cycle_loss_fn(real_photo, cycled_photo, self.lambda_cycle)

            # evaluates total generator loss
            total_monet_gen_loss = monet_gen_loss + total_cycle_loss + self.identity_loss_fn(real_monet, same_monet, self.lambda_cycle)
            total_photo_gen_loss = photo_gen_loss + total_cycle_loss + self.identity_loss_fn(real_photo, same_photo, self.lambda_cycle)

            # evaluates discriminator loss
            monet_disc_loss = self.disc_loss_fn(disc_real_monet, disc_fake_monet)
            photo_disc_loss = self.disc_loss_fn(disc_real_photo, disc_fake_photo)

        # Calculate the gradients for generator and discriminator
        monet_generator_gradients = tape.gradient(total_monet_gen_loss,
                                                  self.m_gen.trainable_variables)
        photo_generator_gradients = tape.gradient(total_photo_gen_loss,
                                                  self.p_gen.trainable_variables)

        monet_discriminator_gradients = tape.gradient(monet_disc_loss,
                                                      self.m_disc.trainable_variables)
        photo_discriminator_gradients = tape.gradient(photo_disc_loss,
                                                      self.p_disc.trainable_variables)

        # Apply the gradients to the optimizer
        self.m_gen_optimizer.apply_gradients(zip(monet_generator_gradients,
                                                 self.m_gen.trainable_variables))

        self.p_gen_optimizer.apply_gradients(zip(photo_generator_gradients,
                                                 self.p_gen.trainable_variables))

        self.m_disc_optimizer.apply_gradients(zip(monet_discriminator_gradients,
                                                  self.m_disc.trainable_variables))

        self.p_disc_optimizer.apply_gradients(zip(photo_discriminator_gradients,
                                                  self.p_disc.trainable_variables))
        
        return {
            "monet_gen_loss": total_monet_gen_loss,
            "photo_gen_loss": total_photo_gen_loss,
            "monet_disc_loss": monet_disc_loss,
            "photo_disc_loss": photo_disc_loss
        }

# %% [markdown]
# # Define Loss Functions

# %%
with strategy.scope():
    def discriminator_loss(real, generated):
        real_loss = tf.keras.losses.BinaryCrossentropy(from_logits=True, reduction=tf.keras.losses.Reduction.NONE)(tf.ones_like(real), real)

        generated_loss = tf.keras.losses.BinaryCrossentropy(from_logits=True, reduction=tf.keras.losses.Reduction.NONE)(tf.zeros_like(generated), generated)

        total_disc_loss = real_loss + generated_loss

        return total_disc_loss * 0.5

# %%
with strategy.scope():
    def generator_loss(generated):
        return tf.keras.losses.BinaryCrossentropy(from_logits=True, reduction=tf.keras.losses.Reduction.NONE)(tf.ones_like(generated), generated)

# %%
with strategy.scope():
    def calc_cycle_loss(real_image, cycled_image, LAMBDA):
        loss1 = tf.reduce_mean(tf.abs(real_image - cycled_image))

        return LAMBDA * loss1

# %%
with strategy.scope():
    def identity_loss(real_image, same_image, LAMBDA):
        loss = tf.reduce_mean(tf.abs(real_image - same_image))
        return LAMBDA * 0.5 * loss

# %% [markdown]
# # Train the CycleGAN

# %%
with strategy.scope():
    monet_generator_optimizer = tf.keras.optimizers.Adam(2e-4, beta_1=0.5)
    photo_generator_optimizer = tf.keras.optimizers.Adam(2e-4, beta_1=0.5)

    monet_discriminator_optimizer = tf.keras.optimizers.Adam(2e-4, beta_1=0.5)
    photo_discriminator_optimizer = tf.keras.optimizers.Adam(2e-4, beta_1=0.5)

# %%
with strategy.scope():
    cycle_gan_model = CycleGan(
        monet_generator, photo_generator, monet_discriminator, photo_discriminator
    )

    cycle_gan_model.compile(
        m_gen_optimizer = monet_generator_optimizer,
        p_gen_optimizer = photo_generator_optimizer,
        m_disc_optimizer = monet_discriminator_optimizer,
        p_disc_optimizer = photo_discriminator_optimizer,
        gen_loss_fn = generator_loss,
        disc_loss_fn = discriminator_loss,
        cycle_loss_fn = calc_cycle_loss,
        identity_loss_fn = identity_loss
    )

# %%
cycle_gan_model.fit(
    tf.data.Dataset.zip((monet_ds, photo_ds)),
    epochs=100
)
# Out:
# Epoch 1/100
# 2022-04-11 06:39:10.912267: W tensorflow/core/common_runtime/bfc_allocator.cc:275] Allocator (GPU_0_bfc) ran out of memory trying to allocate 2.15GiB with freed_by_count=0. The caller indicates that this is not a failure, but may mean that there could be performance gains if more memory were available.
# 2022-04-11 06:39:10.912319: W tensorflow/core/common_runtime/bfc_allocator.cc:275] Allocator (GPU_0_bfc) ran out of memory trying to allocate 2.15GiB with freed_by_count=0. The caller indicates that this is not a failure, but may mean that there could be performance gains if more memory were available.
# 2022-04-11 06:39:11.054841: W tensorflow/core/common_runtime/bfc_allocator.cc:275] Allocator (GPU_0_bfc) ran out of memory trying to allocate 2.15GiB with freed_by_count=0. The caller indicates that this is not a failure, but may mean that there could be performance gains if more memory were available.
# 2022-04-11 06:39:11.054881: W tensorflow/core/common_runtime/bfc_allocator.cc:275] Allocator (GPU_0_bfc) ran out of memory trying to allocate 2.15GiB with freed_by_count=0. The caller indicates that this is not a failure, but may mean that there could be performance gains if more memory were available.
# 2022-04-11 06:39:11.140674: W tensorflow/core/common_runtime/bfc_allocator.cc:275] Allocator (GPU_0_bfc) ran out of memory trying to allocate 2.15GiB with freed_by_count=0. The caller indicates that this is not a failure, but may mean that there could be performance gains if more memory were available.
# 2022-04-11 06:39:11.140722: W tensorflow/core/common_runtime/bfc_allocator.cc:275] Allocator (GPU_0_bfc) ran out of memory trying to allocate 2.15GiB with freed_by_count=0. The caller indicates that this is not a failure, but may mean that there could be performance gains if more memory were available.
# 2022-04-11 06:39:11.241585: W tensorflow/core/common_runtime/bfc_allocator.cc:275] Allocator (GPU_0_bfc) ran out of memory trying to allocate 1.08GiB with freed_by_count=0. The caller indicates that this is not a failure, but may mean that there could be performance gains if more memory were available.
# 2022-04-11 06:39:11.241621: W tensorflow/core/common_runtime/bfc_allocator.cc:275] Allocator (GPU_0_bfc) ran out of memory trying to allocate 1.08GiB with freed_by_count=0. The caller indicates that this is not a failure, but may mean that there could be performance gains if more memory were available.
# 2022-04-11 06:39:11.269429: W tensorflow/core/common_runtime/bfc_allocator.cc:275] Allocator (GPU_0_bfc) ran out of memory trying to allocate 1.08GiB with freed_by_count=0. The caller indicates that this is not a failure, but may mean that there could be performance gains if more memory were available.
# 2022-04-11 06:39:11.269462: W tensorflow/core/common_runtime/bfc_allocator.cc:275] Allocator (GPU_0_bfc) ran out of memory trying to allocate 1.08GiB with freed_by_count=0. The caller indicates that this is not a failure, but may mean that there could be performance gains if more memory were available.
# 300/300 [==============================] - 235s 679ms/step - monet_gen_loss: 5.1350 - photo_gen_loss: 5.3369 - monet_disc_loss: 0.6545 - photo_disc_loss: 0.6209
# Epoch 2/100
# 300/300 [==============================] - 204s 682ms/step - monet_gen_loss: 3.5373 - photo_gen_loss: 3.6662 - monet_disc_loss: 0.6735 - photo_disc_loss: 0.6435
# Epoch 3/100
# 300/300 [==============================] - 205s 683ms/step - monet_gen_loss: 3.4800 - photo_gen_loss: 3.5815 - monet_disc_loss: 0.6521 - photo_disc_loss: 0.6263
# Epoch 4/100
# 300/300 [==============================] - 202s 673ms/step - monet_gen_loss: 3.3007 - photo_gen_loss: 3.4787 - monet_disc_loss: 0.6596 - photo_disc_loss: 0.6104
# Epoch 5/100
# 300/300 [==============================] - 199s 663ms/step - monet_gen_loss: 3.1871 - photo_gen_loss: 3.3128 - monet_disc_loss: 0.6435 - photo_disc_loss: 0.6037
# Epoch 6/100
# 300/300 [==============================] - 205s 683ms/step - monet_gen_loss: 3.1509 - photo_gen_loss: 3.2790 - monet_disc_loss: 0.6274 - photo_disc_loss: 0.5989
# Epoch 7/100
# 300/300 [==============================] - 205s 682ms/step - monet_gen_loss: 3.1337 - photo_gen_loss: 3.2238 - monet_disc_loss: 0.6206 - photo_disc_loss: 0.6112
# Epoch 8/100
# 300/300 [==============================] - 193s 644ms/step - monet_gen_loss: 3.1208 - photo_gen_loss: 3.1972 - monet_disc_loss: 0.6131 - photo_disc_loss: 0.6041
# Epoch 9/100
# 300/300 [==============================] - 189s 628ms/step - monet_gen_loss: 3.1447 - photo_gen_loss: 3.2099 - monet_disc_loss: 0.6054 - photo_disc_loss: 0.6018
# Epoch 10/100
# 300/300 [==============================] - 188s 628ms/step - monet_gen_loss: 3.1355 - photo_gen_loss: 3.1887 - monet_disc_loss: 0.6044 - photo_disc_loss: 0.5999
# Epoch 11/100
# 300/300 [==============================] - 188s 628ms/step - monet_gen_loss: 3.1054 - photo_gen_loss: 3.1657 - monet_disc_loss: 0.6030 - photo_disc_loss: 0.6109
# Epoch 12/100
# 300/300 [==============================] - 188s 628ms/step - monet_gen_loss: 3.0918 - photo_gen_loss: 3.1379 - monet_disc_loss: 0.6061 - photo_disc_loss: 0.6098
# Epoch 13/100
# 300/300 [==============================] - 188s 628ms/step - monet_gen_loss: 3.0503 - photo_gen_loss: 3.1004 - monet_disc_loss: 0.6041 - photo_disc_loss: 0.6098
# Epoch 14/100
# 300/300 [==============================] - 188s 628ms/step - monet_gen_loss: 3.0142 - photo_gen_loss: 3.0629 - monet_disc_loss: 0.6018 - photo_disc_loss: 0.6077
# Epoch 15/100
# 300/300 [==============================] - 189s 628ms/step - monet_gen_loss: 2.9753 - photo_gen_loss: 3.0329 - monet_disc_loss: 0.6055 - photo_disc_loss: 0.6061
# Epoch 16/100
# 300/300 [==============================] - 188s 628ms/step - monet_gen_loss: 2.9361 - photo_gen_loss: 3.0135 - monet_disc_loss: 0.6097 - photo_disc_loss: 0.6082
# Epoch 17/100
# 300/300 [==============================] - 188s 628ms/step - monet_gen_loss: 2.8968 - photo_gen_loss: 2.9827 - monet_disc_loss: 0.6101 - photo_disc_loss: 0.6106
# Epoch 18/100
# 300/300 [==============================] - 188s 628ms/step - monet_gen_loss: 2.8594 - photo_gen_loss: 2.9387 - monet_disc_loss: 0.6120 - photo_disc_loss: 0.6156
# Epoch 19/100
# 300/300 [==============================] - 188s 628ms/step - monet_gen_loss: 2.8378 - photo_gen_loss: 2.9140 - monet_disc_loss: 0.6126 - photo_disc_loss: 0.6165
# Epoch 20/100
# 300/300 [==============================] - 188s 628ms/step - monet_gen_loss: 2.7977 - photo_gen_loss: 2.8894 - monet_disc_loss: 0.6181 - photo_disc_loss: 0.6230
# Epoch 21/100
# 300/300 [==============================] - 188s 628ms/step - monet_gen_loss: 2.7676 - photo_gen_loss: 2.8550 - monet_disc_loss: 0.6159 - photo_disc_loss: 0.6214
# Epoch 22/100
# 300/300 [==============================] - 188s 628ms/step - monet_gen_loss: 2.7455 - photo_gen_loss: 2.8248 - monet_disc_loss: 0.6212 - photo_disc_loss: 0.6271
# Epoch 23/100
# 300/300 [==============================] - 188s 628ms/step - monet_gen_loss: 2.7189 - photo_gen_loss: 2.8102 - monet_disc_loss: 0.6224 - photo_disc_loss: 0.6241
# Epoch 24/100
# 300/300 [==============================] - 188s 628ms/step - monet_gen_loss: 2.6906 - photo_gen_loss: 2.7838 - monet_disc_loss: 0.6258 - photo_disc_loss: 0.6217
# Epoch 25/100
# 300/300 [==============================] - 188s 628ms/step - monet_gen_loss: 2.6575 - photo_gen_loss: 2.7713 - monet_disc_loss: 0.6315 - photo_disc_loss: 0.6223
# Epoch 26/100
# 300/300 [==============================] - 188s 628ms/step - monet_gen_loss: 2.6660 - photo_gen_loss: 2.7905 - monet_disc_loss: 0.6196 - photo_disc_loss: 0.6019
# Epoch 27/100
# 300/300 [==============================] - 188s 628ms/step - monet_gen_loss: 2.6639 - photo_gen_loss: 2.7779 - monet_disc_loss: 0.6143 - photo_disc_loss: 0.6018
# Epoch 28/100
# 300/300 [==============================] - 188s 628ms/step - monet_gen_loss: 2.8005 - photo_gen_loss: 2.9085 - monet_disc_loss: 0.6170 - photo_disc_loss: 0.5970
# Epoch 29/100
# 300/300 [==============================] - 188s 628ms/step - monet_gen_loss: 2.6333 - photo_gen_loss: 2.7748 - monet_disc_loss: 0.6250 - photo_disc_loss: 0.5982
# Epoch 30/100
# 300/300 [==============================] - 188s 628ms/step - monet_gen_loss: 2.6545 - photo_gen_loss: 2.8121 - monet_disc_loss: 0.6348 - photo_disc_loss: 0.6121
# Epoch 31/100
# 300/300 [==============================] - 188s 627ms/step - monet_gen_loss: 2.6562 - photo_gen_loss: 2.8097 - monet_disc_loss: 0.6214 - photo_disc_loss: 0.6022
# Epoch 32/100
# 300/300 [==============================] - 188s 628ms/step - monet_gen_loss: 2.7320 - photo_gen_loss: 2.9670 - monet_disc_loss: 0.6144 - photo_disc_loss: 0.5753
# Epoch 33/100
# 300/300 [==============================] - 188s 628ms/step - monet_gen_loss: 2.6350 - photo_gen_loss: 2.7857 - monet_disc_loss: 0.6205 - photo_disc_loss: 0.5978
# Epoch 34/100
# 300/300 [==============================] - 188s 628ms/step - monet_gen_loss: 2.7866 - photo_gen_loss: 2.9895 - monet_disc_loss: 0.5824 - photo_disc_loss: 0.5417
# Epoch 35/100
# 300/300 [==============================] - 188s 628ms/step - monet_gen_loss: 2.6819 - photo_gen_loss: 2.8352 - monet_disc_loss: 0.6253 - photo_disc_loss: 0.5856
# Epoch 36/100
# 300/300 [==============================] - 188s 628ms/step - monet_gen_loss: 2.6123 - photo_gen_loss: 2.7604 - monet_disc_loss: 0.6238 - photo_disc_loss: 0.5962
# Epoch 37/100
# 300/300 [==============================] - 188s 627ms/step - monet_gen_loss: 2.6166 - photo_gen_loss: 2.7675 - monet_disc_loss: 0.6212 - photo_disc_loss: 0.5908
# Epoch 38/100
# 300/300 [==============================] - 188s 627ms/step - monet_gen_loss: 2.6658 - photo_gen_loss: 2.8731 - monet_disc_loss: 0.6047 - photo_disc_loss: 0.5680
# Epoch 39/100
# 300/300 [==============================] - 188s 627ms/step - monet_gen_loss: 2.8084 - photo_gen_loss: 2.9200 - monet_disc_loss: 0.5881 - photo_disc_loss: 0.5668
# Epoch 40/100
# 300/300 [==============================] - 188s 627ms/step - monet_gen_loss: 2.7120 - photo_gen_loss: 2.8603 - monet_disc_loss: 0.5960 - photo_disc_loss: 0.5642
# Epoch 41/100
# 300/300 [==============================] - 188s 627ms/step - monet_gen_loss: 2.6916 - photo_gen_loss: 2.8350 - monet_disc_loss: 0.6084 - photo_disc_loss: 0.5753
# Epoch 42/100
# 300/300 [==============================] - 188s 627ms/step - monet_gen_loss: 2.7791 - photo_gen_loss: 2.9572 - monet_disc_loss: 0.5892 - photo_disc_loss: 0.5490
# Epoch 43/100
# 300/300 [==============================] - 188s 627ms/step - monet_gen_loss: 2.7694 - photo_gen_loss: 2.9243 - monet_disc_loss: 0.6034 - photo_disc_loss: 0.5557
# Epoch 44/100
# 300/300 [==============================] - 188s 627ms/step - monet_gen_loss: 2.7522 - photo_gen_loss: 2.9705 - monet_disc_loss: 0.5983 - photo_disc_loss: 0.5468
# Epoch 45/100
# 300/300 [==============================] - 188s 627ms/step - monet_gen_loss: 2.6675 - photo_gen_loss: 2.8568 - monet_disc_loss: 0.6036 - photo_disc_loss: 0.5621
# Epoch 46/100
# 300/300 [==============================] - 188s 627ms/step - monet_gen_loss: 2.7661 - photo_gen_loss: 3.0247 - monet_disc_loss: 0.5946 - photo_disc_loss: 0.5376
# Epoch 47/100
# 300/300 [==============================] - 188s 628ms/step - monet_gen_loss: 3.0440 - photo_gen_loss: 3.0593 - monet_disc_loss: 0.5296 - photo_disc_loss: 0.5280
# Epoch 48/100
# 300/300 [==============================] - 188s 627ms/step - monet_gen_loss: 3.0226 - photo_gen_loss: 3.0669 - monet_disc_loss: 0.5487 - photo_disc_loss: 0.5364
# Epoch 49/100
# 300/300 [==============================] - 188s 627ms/step - monet_gen_loss: 2.7394 - photo_gen_loss: 2.8939 - monet_disc_loss: 0.6089 - photo_disc_loss: 0.5632
# Epoch 50/100
# 300/300 [==============================] - 188s 628ms/step - monet_gen_loss: 2.7213 - photo_gen_loss: 2.9006 - monet_disc_loss: 0.5912 - photo_disc_loss: 0.5467
# Epoch 51/100
# 300/300 [==============================] - 188s 627ms/step - monet_gen_loss: 2.6939 - photo_gen_loss: 2.8273 - monet_disc_loss: 0.5940 - photo_disc_loss: 0.5607
# Epoch 52/100
# 300/300 [==============================] - 188s 627ms/step - monet_gen_loss: 2.7179 - photo_gen_loss: 2.8377 - monet_disc_loss: 0.5910 - photo_disc_loss: 0.5558
# Epoch 53/100
# 300/300 [==============================] - 188s 627ms/step - monet_gen_loss: 2.9434 - photo_gen_loss: 2.9845 - monet_disc_loss: 0.5432 - photo_disc_loss: 0.5300
# Epoch 54/100
# 300/300 [==============================] - 188s 627ms/step - monet_gen_loss: 2.9378 - photo_gen_loss: 3.0590 - monet_disc_loss: 0.5655 - photo_disc_loss: 0.5237
# Epoch 55/100
# 300/300 [==============================] - 188s 627ms/step - monet_gen_loss: 2.8410 - photo_gen_loss: 2.9817 - monet_disc_loss: 0.5864 - photo_disc_loss: 0.5280
# Epoch 56/100
# 300/300 [==============================] - 188s 628ms/step - monet_gen_loss: 2.8299 - photo_gen_loss: 2.9256 - monet_disc_loss: 0.5642 - photo_disc_loss: 0.5412
# Epoch 57/100
# 300/300 [==============================] - 188s 627ms/step - monet_gen_loss: 3.0352 - photo_gen_loss: 2.9856 - monet_disc_loss: 0.5258 - photo_disc_loss: 0.5288
# Epoch 58/100
# 300/300 [==============================] - 188s 627ms/step - monet_gen_loss: 3.0680 - photo_gen_loss: 3.1205 - monet_disc_loss: 0.5360 - photo_disc_loss: 0.5257
# Epoch 59/100
# 300/300 [==============================] - 188s 627ms/step - monet_gen_loss: 2.9386 - photo_gen_loss: 3.1753 - monet_disc_loss: 0.5683 - photo_disc_loss: 0.5018
# Epoch 60/100
# 300/300 [==============================] - 188s 627ms/step - monet_gen_loss: 2.8426 - photo_gen_loss: 2.9808 - monet_disc_loss: 0.5607 - photo_disc_loss: 0.5326
# Epoch 61/100
# 300/300 [==============================] - 188s 628ms/step - monet_gen_loss: 2.8754 - photo_gen_loss: 2.9657 - monet_disc_loss: 0.5604 - photo_disc_loss: 0.5368
# Epoch 62/100
# 300/300 [==============================] - 188s 627ms/step - monet_gen_loss: 2.8211 - photo_gen_loss: 2.9253 - monet_disc_loss: 0.5709 - photo_disc_loss: 0.5444
# Epoch 63/100
# 300/300 [==============================] - 188s 627ms/step - monet_gen_loss: 2.8695 - photo_gen_loss: 2.9423 - monet_disc_loss: 0.5622 - photo_disc_loss: 0.5392
# Epoch 64/100
# 300/300 [==============================] - 188s 628ms/step - monet_gen_loss: 2.8892 - photo_gen_loss: 2.9911 - monet_disc_loss: 0.5532 - photo_disc_loss: 0.5310
# Epoch 65/100
# 300/300 [==============================] - 188s 628ms/step - monet_gen_loss: 2.8580 - photo_gen_loss: 2.9329 - monet_disc_loss: 0.5592 - photo_disc_loss: 0.5487
# Epoch 66/100
# 300/300 [==============================] - 188s 628ms/step - monet_gen_loss: 3.0437 - photo_gen_loss: 3.0222 - monet_disc_loss: 0.5385 - photo_disc_loss: 0.5365
# Epoch 67/100
# 300/300 [==============================] - 188s 628ms/step - monet_gen_loss: 2.8774 - photo_gen_loss: 2.9270 - monet_disc_loss: 0.5532 - photo_disc_loss: 0.5527
# Epoch 68/100
# 300/300 [==============================] - 188s 627ms/step - monet_gen_loss: 2.8978 - photo_gen_loss: 2.9766 - monet_disc_loss: 0.5480 - photo_disc_loss: 0.5355
# Epoch 69/100
# 300/300 [==============================] - 188s 628ms/step - monet_gen_loss: 2.8377 - photo_gen_loss: 2.8867 - monet_disc_loss: 0.5559 - photo_disc_loss: 0.5509
# Epoch 70/100
# 300/300 [==============================] - 188s 628ms/step - monet_gen_loss: 2.8203 - photo_gen_loss: 2.8650 - monet_disc_loss: 0.5544 - photo_disc_loss: 0.5648
# Epoch 71/100
# 300/300 [==============================] - 188s 628ms/step - monet_gen_loss: 2.8229 - photo_gen_loss: 2.8577 - monet_disc_loss: 0.5621 - photo_disc_loss: 0.5595
# Epoch 72/100
# 300/300 [==============================] - 188s 628ms/step - monet_gen_loss: 2.9196 - photo_gen_loss: 2.9497 - monet_disc_loss: 0.5536 - photo_disc_loss: 0.5467
# Epoch 73/100
# 300/300 [==============================] - 188s 627ms/step - monet_gen_loss: 3.1108 - photo_gen_loss: 3.0930 - monet_disc_loss: 0.5318 - photo_disc_loss: 0.5237
# Epoch 74/100
# 300/300 [==============================] - 188s 627ms/step - monet_gen_loss: 2.9551 - photo_gen_loss: 3.0218 - monet_disc_loss: 0.5449 - photo_disc_loss: 0.5282
# Epoch 75/100
# 300/300 [==============================] - 188s 627ms/step - monet_gen_loss: 2.9403 - photo_gen_loss: 2.9566 - monet_disc_loss: 0.5560 - photo_disc_loss: 0.5497
# Epoch 76/100
# 300/300 [==============================] - 188s 627ms/step - monet_gen_loss: 2.8568 - photo_gen_loss: 2.8977 - monet_disc_loss: 0.5564 - photo_disc_loss: 0.5499
# Epoch 77/100
# 300/300 [==============================] - 188s 627ms/step - monet_gen_loss: 2.8502 - photo_gen_loss: 2.8925 - monet_disc_loss: 0.5638 - photo_disc_loss: 0.5664
# Epoch 78/100
# 300/300 [==============================] - 188s 627ms/step - monet_gen_loss: 3.0489 - photo_gen_loss: 2.9946 - monet_disc_loss: 0.5329 - photo_disc_loss: 0.5444
# Epoch 79/100
# 300/300 [==============================] - 188s 627ms/step - monet_gen_loss: 3.1926 - photo_gen_loss: 3.1017 - monet_disc_loss: 0.5226 - photo_disc_loss: 0.5247
# Epoch 80/100
# 300/300 [==============================] - 188s 627ms/step - monet_gen_loss: 3.0154 - photo_gen_loss: 3.0676 - monet_disc_loss: 0.5545 - photo_disc_loss: 0.5218
# Epoch 81/100
# 300/300 [==============================] - 188s 628ms/step - monet_gen_loss: 2.9510 - photo_gen_loss: 3.0007 - monet_disc_loss: 0.5531 - photo_disc_loss: 0.5445
# Epoch 82/100
# 300/300 [==============================] - 188s 627ms/step - monet_gen_loss: 2.8912 - photo_gen_loss: 2.9618 - monet_disc_loss: 0.5478 - photo_disc_loss: 0.5522
# Epoch 83/100
# 300/300 [==============================] - 188s 627ms/step - monet_gen_loss: 2.8482 - photo_gen_loss: 2.8877 - monet_disc_loss: 0.5585 - photo_disc_loss: 0.5534
# Epoch 84/100
# 300/300 [==============================] - 188s 628ms/step - monet_gen_loss: 2.8972 - photo_gen_loss: 2.9698 - monet_disc_loss: 0.5679 - photo_disc_loss: 0.5399
# Epoch 85/100
# 300/300 [==============================] - 188s 627ms/step - monet_gen_loss: 2.8459 - photo_gen_loss: 2.8945 - monet_disc_loss: 0.5640 - photo_disc_loss: 0.5552
# Epoch 86/100
# 300/300 [==============================] - 188s 627ms/step - monet_gen_loss: 2.8830 - photo_gen_loss: 2.9222 - monet_disc_loss: 0.5611 - photo_disc_loss: 0.5549
# Epoch 87/100
# 300/300 [==============================] - 188s 628ms/step - monet_gen_loss: 2.9858 - photo_gen_loss: 3.0419 - monet_disc_loss: 0.5596 - photo_disc_loss: 0.5356
# Epoch 88/100
# 300/300 [==============================] - 188s 628ms/step - monet_gen_loss: 2.9117 - photo_gen_loss: 2.9357 - monet_disc_loss: 0.5514 - photo_disc_loss: 0.5544
# Epoch 89/100
# 300/300 [==============================] - 188s 628ms/step - monet_gen_loss: 2.9685 - photo_gen_loss: 2.9582 - monet_disc_loss: 0.5460 - photo_disc_loss: 0.5536
# Epoch 90/100
# 300/300 [==============================] - 188s 627ms/step - monet_gen_loss: 3.1427 - photo_gen_loss: 3.2874 - monet_disc_loss: 0.5288 - photo_disc_loss: 0.4591
# Epoch 91/100
# 300/300 [==============================] - 188s 628ms/step - monet_gen_loss: 2.9714 - photo_gen_loss: 3.0286 - monet_disc_loss: 0.5469 - photo_disc_loss: 0.5211
# Epoch 92/100
# 300/300 [==============================] - 188s 628ms/step - monet_gen_loss: 2.9217 - photo_gen_loss: 2.9430 - monet_disc_loss: 0.5508 - photo_disc_loss: 0.5531
# Epoch 93/100
# 300/300 [==============================] - 188s 627ms/step - monet_gen_loss: 2.9970 - photo_gen_loss: 3.1203 - monet_disc_loss: 0.5482 - photo_disc_loss: 0.5093
# Epoch 94/100
# 300/300 [==============================] - 188s 627ms/step - monet_gen_loss: 3.1481 - photo_gen_loss: 3.9192 - monet_disc_loss: 0.5214 - photo_disc_loss: 0.3164
# Epoch 95/100
# 300/300 [==============================] - 188s 627ms/step - monet_gen_loss: 3.2220 - photo_gen_loss: 3.6470 - monet_disc_loss: 0.5301 - photo_disc_loss: 0.4123
# Epoch 96/100
# 300/300 [==============================] - 188s 627ms/step - monet_gen_loss: 3.0940 - photo_gen_loss: 3.3193 - monet_disc_loss: 0.5210 - photo_disc_loss: 0.4770
# Epoch 97/100
# 300/300 [==============================] - 188s 628ms/step - monet_gen_loss: 2.9878 - photo_gen_loss: 3.2651 - monet_disc_loss: 0.5548 - photo_disc_loss: 0.4603
# Epoch 98/100
# 300/300 [==============================] - 188s 627ms/step - monet_gen_loss: 2.9949 - photo_gen_loss: 3.2097 - monet_disc_loss: 0.5451 - photo_disc_loss: 0.5053
# Epoch 99/100
# 300/300 [==============================] - 188s 627ms/step - monet_gen_loss: 2.9755 - photo_gen_loss: 3.1238 - monet_disc_loss: 0.5456 - photo_disc_loss: 0.5059
# Epoch 100/100
# 300/300 [==============================] - 188s 627ms/step - monet_gen_loss: 2.9448 - photo_gen_loss: 3.0439 - monet_disc_loss: 0.5670 - photo_disc_loss: 0.5190

# %%
_, ax = plt.subplots(5, 2, figsize=(24, 24))
for i, img in enumerate(photo_ds.take(5)):
    prediction = monet_generator(img, training=False)[0].numpy()
    prediction = (prediction * 127.5 + 127.5).astype(np.uint8)
    img = (img[0] * 127.5 + 127.5).numpy().astype(np.uint8)

    ax[i, 0].imshow(img)
    ax[i, 1].imshow(prediction)
    ax[i, 0].set_title("Input Photo")
    ax[i, 1].set_title("Monet-esque")
    ax[i, 0].axis("off")
    ax[i, 1].axis("off")
plt.show()

# %%
import PIL
! mkdir ./images
# Out:
# mkdir: cannot create directory ‘./images’: File exists

# %% [markdown]
# # Create The Submission Data

# %%
i = 1
for img in photo_ds:
    prediction = monet_generator(img, training=False)[0].numpy()
    prediction = (prediction * 127.5 + 127.5).astype(np.uint8)
    im = PIL.Image.fromarray(prediction)
    im.save("./images/" + str(i) + ".jpg")
    i += 1

# %%
import shutil
shutil.make_archive("images", 'zip', "images")
# Out:
# '/home/rsandor/Monet/images.zip'

# %% [markdown]
# # Improving the model

# %% [markdown]
# ## One-sided Label smoothing?

# %% [markdown]
# Penalize the descriminator for overconfidence on a model

# %% [markdown]
# ## Replay?

# %%
class ReplayMemory:
    def __init__(self, capacity):
        self.capacity = capacity
        self.memory = []
        
    def push(self, state, action, reward, next_state):
        if len(self.memory) > self.capacity:
            self.memory.pop()
        self.memory.append(transition(state, action, reward, next_state))
        
    def sample_batch(self, batch_size):
        if len(self) > batch_size:
            return random.sample(self.memory, batch_size)
        return []
    
    def __len__(self):
        return len(self.memory)

# %% [markdown]
# ## More Epochs?
